# %%
import regex as re
import pandas as pd

# %%
def solo_emojis(texto: str) -> bool:
    """
    Retorna True si el texto contiene solo emojis (y caracteres invisibles como ZWJ o VS16),
    y False si hay algún otro carácter (letras, números, espacios, puntuación, etc.).
    """
    # Patrón que coincide con cualquier emoji (incluyendo secuencias complejas)
    patron_emoji = re.compile(r'\p{Emoji_Presentation}|\p{Extended_Pictographic}')

    # Eliminar posibles caracteres de control/unión que no son emojis por sí mismos
    texto_limpio = re.sub(r'[\u200d\uFE0F\uFE0E\u061C\u200E\u200F\u202A-\u202E]', '', texto)

    if not texto_limpio:
        return False

    # Buscar todos los "trozos" que no son emojis (caracteres normales)
    resto = re.sub(patron_emoji, '', texto_limpio)

    # Si después de quitar emojis queda algo, hay caracteres no-emoji
    return len(resto.strip()) == 0


def indices(datos: str) -> str:
    #limpiamos celdas vacias
    borrar = []
    for i in range(len(datos)):
        if ((type(datos[i]) != str)):
            borrar.append(i)
        elif solo_emojis(datos[i]):
            borrar.append(i)
        elif (datos[i] == '[Sticker] '):
            borrar.append(i)
        elif (datos[i] == ''):
            borrar.append(i)
    return borrar

# %%
datos = pd.read_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/raw/tiktok infraestructura.csv', usecols = ['text'])

datos_limpios = datos.drop(indices(datos['text']))

datos_limpios.to_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/processed/tiktok_infraes_limpio.csv', encoding = 'utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4493/410181545.py in <cell line: 0>()
# ----> 1 datos = pd.read_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/raw/tiktok infraestructura.csv', usecols = ['text'])
#       2
#       3 datos_limpios = datos.drop(indices(datos['text']))
#       4
#       5 datos_limpios.to_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/processed/tiktok_infraes_limpio.csv', encoding = 'utf-8-sig')
#
# ...

# %%
datos = pd.read_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/raw/tiktok seguridad.csv', usecols = ['text'])

datos_limpios = datos.drop(indices(datos['text']))

datos_limpios.to_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/processed/tiktok_seguridad_limpio.csv', encoding = 'utf-8-sig')

# %%
datos = pd.read_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/raw/tiktok turismo.csv', usecols = ['text'])

datos_limpios = datos.drop(indices(datos['text']))

datos_limpios.to_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/processed/tiktok_turismo_limpio.csv', encoding = 'utf-8-sig')

# %%
datos = pd.read_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/raw/tiktok infraestructura_evaluacion_humano.csv', usecols = ['text'])

datos_limpios = datos.drop(indices(datos['text']))

datos_limpios.to_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/processed/tiktok_infraestructura_evaluacion_humano_limpio.csv', encoding = 'utf-8-sig')

# %%
datos = pd.read_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/raw/tiktok seguridad_evaluacion-humano.csv', usecols = ['text'])

datos_limpios = datos.drop(indices(datos['text']))

datos_limpios.to_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/processed/tiktok_seguridad_evaluacion_humano_limpio.csv', encoding = 'utf-8-sig')

# %%
datos = pd.read_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/raw/tiktok turismo_evaluacion-humano.csv', usecols = ['text'])

datos_limpios = datos.drop(indices(datos['text']))

datos_limpios.to_csv('C:/Users/inqui/OneDrive/Desktop/Clases/26-2/LLM_PROJECT_1/datos/processed/tiktok_turismo_evaluacion_humano_limpio.csv', encoding = 'utf-8-sig')
